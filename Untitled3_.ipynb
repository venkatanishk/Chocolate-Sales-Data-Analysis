# %%
import numpy as np # linear algebra
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df_choc = pd.read_csv("Chocolate Sales.csv")
df_choc.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
df_choc.shape
# Out:
# (1094, 6)

# %%
df_choc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   object
#  4   Amount         1094 non-null   object
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 51.4+ KB

# %%
#change type and format of Date Column
df_choc['Date'] = pd.to_datetime(df_choc['Date'], format='%d-%b-%y')

#Remove "$" and "," and "spaces" and change type into float of Amount Column
df_choc['Amount'] = df_choc['Amount'].str.replace('$', '', regex=False).str.replace(',', '', regex=False).str.strip().astype(float)

# %%
df_choc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   datetime64[ns]
#  4   Amount         1094 non-null   float64
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 51.4+ KB

# %%
df_choc.sample(5)
# Out:
#             Sales Person      Country             Product       Date  Amount  \
# 10   Rafaelita Blaksland           UK  Smooth Sliky Salty 2022-01-13  4704.0
# 797       Andria Kimpton    Australia  Manuka Honey Choco 2022-03-30  9744.0
# 354  Dennison Crosswaite  New Zealand       Drinking Coco 2022-01-11  4109.0
# 368       Mallorie Waber          USA        Almond Choco 2022-01-28  6986.0
# 9            Brien Boise    Australia     99% Dark & Pure 2022-07-04  2835.0
#
#      Boxes Shipped
# 10              62
# 797            377
# 354            197
# 368            368
# 9              102

# %%
df_choc.isnull().sum()
# Out:
# Sales Person     0
# Country          0
# Product          0
# Date             0
# Amount           0
# Boxes Shipped    0
# dtype: int64

# %%
df_choc.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sales by Country
country_sales = df_choc.groupby('Country')['Amount'].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data= country_sales, x='Amount', y='Country')
plt.title('Total Sales by Country')
plt.xlabel('Sales Amount (1M)')
plt.ylabel('Country')
plt.show()

# %%
# Salesperson Performance
top_salespeople = df_choc.groupby('Sales Person')['Amount'].sum().sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=top_salespeople, x='Amount', y='Sales Person')
plt.title('Top 10 Salespeople by Total Sales')
plt.xlabel('Total Sales')
plt.ylabel('Sales Person')
plt.show()

# %%
# Average Sale per Box by Product

df_choc['Revenue per Box'] = df_choc['Amount'] / df_choc['Boxes Shipped']
avg_per_box = df_choc.groupby('Product')['Revenue per Box'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(data=avg_per_box, x='Revenue per Box', y='Product')
plt.title('Average Revenue per Box by Product')
plt.show()

# %%
# Total Boxes Shipped by Country

country_boxes = df_choc.groupby('Country')['Boxes Shipped'].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=country_boxes, y='Boxes Shipped', x='Country')
plt.title('Total Boxes Shipped by Country')
plt.xlabel('Country')
plt.ylabel('Boxes Shipped')
plt.show()

# %%
 #Product Sales Distribution

plt.figure(figsize=(10, 6))
sns.barplot(data=df_choc, x='Product', y='Amount')
plt.title('Sales Amount Distribution by Product')
plt.xticks(rotation=45)
plt.show()

# %%
# Sales Distribution per Salesperson

plt.figure(figsize=(14, 6))
sns.boxplot(data=df_choc, x='Sales Person', y='Amount')
plt.title('Sales Distribution per Salesperson')
plt.xticks(rotation=90)
plt.show()

# %%
# Boxes Shipped vs. Amount

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_choc, x='Boxes Shipped', y='Amount', hue='Product')
plt.title('Boxes Shipped vs. Amount')
plt.xlabel('Boxes Shipped')
plt.ylabel('Sales Amount')
plt.show()
